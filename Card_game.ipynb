# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ Automatic CARD GAME PLAY @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
## 52 card
# each card has power
# shuffle
# paert it to two
# 2 player
## 2 set of card to each player
##

# %%
suits = ["hearts", "diamonds", "spades","clubs"]
ranks = ["two","three","four","five","six","seven","eight","nine","ten","jack","queen","king","ace"]
value = {"one":1,"two":2,"three":3,"four":4,"five":5,"six":6,"seven":7,"eight":8,"nine":9,"ten":10,"jack":11,"queen":12,"king":13,"ace":14}

# %%
import random
class Card():
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = value[rank]
    def value(self):
        self.value = value[rank]
        
    def __str__(self):
        return f"{self.rank} of {self.suit}"

# %%
class CardDeck:
    def __init__(self):
        self.card_deck = []

        
        for rank in ranks:
            for suit in suits:
                card = Card(suit,rank)
                self.card_deck.append(card)
               
    def Shuffle(self):
        random.shuffle(self.card_deck)
    def deal(self):
        return self.card_deck.pop(0)

# %%
class player(Card):
    def __init__(self,name):
        self.name = name    
        self.player_cards = []
        
    def add_player_card(self,cards):
        self.cards = cards
        if type(cards) == type([]):
             self.player_cards.extend(cards)
        else:
             self.player_cards.append(cards) 
    def remove_player_card(self):
        return self.player_cards.pop(0)
    def value(self):
        self.value = value[rank]
    def __str__(self):
        return f"Player {self.name} has {len(self.player_cards)} cards in their hand "

# %%
###########################################################################################################3

# %%
Game = CardDeck()

# %%
Game.card_deck
Game.Shuffle()

# %%
a = Game.card_deck[0].value
print(a)
# Out:
# 10

# %%
player_one = player("player_one")
player_two = player("player_two")

##############################################################################################################
for n in range(26):
    player_one.add_player_card(Game.deal())
    player_two.add_player_card(Game.deal())
print(player_one)
print(player_two)
print(len(Game.card_deck))
# Out:
# Player player_one has 26 cards in their hand
# Player player_two has 26 cards in their hand
# 0

# %%
condition = True
rounds = 0
print("###########################################   GAME STARTS #################################################")
while condition:
    
    player_one_table =[]
    player_two_table =[]
    if len(player_one.player_cards) == 0:
        print("Player_one has no cards, and player_two wins the match")
        condition = False
        break
    elif len(player_two.player_cards) == 0:
        print("Player_two has no cards, and player_one wins the match")
        condition = False
        break
    else:
       
        war = True
        while war:
        
            player_one_table.append(player_one.remove_player_card())
            player_two_table.append(player_two.remove_player_card())
        
    
        
            if player_one_table[-1].value > player_two_table[-1].value:
                rounds = rounds + 1
                print("   ")
                print(f"###################  ROUND  {rounds}  ############################################################")
                print(f"player one gets {len(player_two_table)} cards")
                
                print(f"Player one wins {player_one_table[-1]} > {player_two_table[-1]}")
                player_one_table.extend(player_two_table)
                player_two_table = []
                player_one.player_cards.extend(player_one_table)
                player_two.player_cards.extend(player_two_table)
                print(f"player 1 has {len(player_one.player_cards)} and player 2 has {len(player_two.player_cards)} ")
                
                war = False
                break
                      
            if player_one_table[-1].value < player_two_table[-1].value:
                rounds = rounds + 1
                print("   ")
                print(f"###################  ROUND   {rounds}  ############################################################")
                print(f"player two gets {len(player_one_table)} cards")
                
                print(f"Player two wins {player_one_table[-1]} < {player_two_table[-1]}")
                player_two_table.extend(player_one_table)
                player_one_table = []
                player_one.player_cards.extend(player_one_table)
                player_two.player_cards.extend(player_two_table)
                print(f"player 2 has {len(player_one.player_cards)} and player 1 has {len(player_two.player_cards)} ")
                
                war = False
                break
                      
            if player_one_table[-1].value == player_two_table[-1].value:
                rounds = rounds + 1
                print("   ")
                print(f"###################  ROUND  {rounds}  #############################################################")
                print("Its a WAR !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
                print(f"WAR {player_one_table[-1]} == {player_two_table[-1]}")
                
                if len(player_one.player_cards) <= 5:
                    print("Player_one lose the war due to less cards, and player_two wins the match")
                    condition = False
                    break
                elif len(player_two.player_cards) <= 5:
                    print("Player_two lose the war due to less cards, and player_one wins the match")
                   
                    condition = False
                    break
                else:
                    for n in range(5):
                        player_one_table.append(player_one.remove_player_card())
                        player_two_table.append(player_two.remove_player_card())
                
print("###########################################   GAME OVER #################################################")
# Out:
# ###########################################   GAME STARTS #################################################
#
# ###################  ROUND  1  ############################################################
# player one gets 1 cards
# Player one wins ten of diamonds > four of spades
# player 1 has 27 and player 2 has 25
#
# ###################  ROUND   2  ############################################################
# player two gets 1 cards
# Player two wins queen of clubs < king of hearts
# player 2 has 26 and player 1 has 26
#
# ###################  ROUND  3  ############################################################
# player one gets 1 cards
# Player one wins six of hearts > two of hearts
# player 1 has 27 and player 2 has 25
#
# ###################  ROUND  4  ############################################################
# player one gets 1 cards
# Player one wins nine of diamonds > five of diamonds
# player 1 has 28 and player 2 has 24
#
# ...

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ DUAL PLAYER  BLACK JACK   @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
suits = ["hearts", "diamonds", "spades","clubs"]
ranks = ["two","three","four","five","six","seven","eight","nine","ten","jack","queen","king","ace"]
value = {"one":1,"two":2,"three":3,"four":4,"five":5,"six":6,"seven":7,"eight":8,"nine":9,"ten":10,"jack":10,"queen":10,"king":10,"ace":11}

# %%
import random
class Card():
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = value[rank]
    def value(self):
        self.value = value[rank]
        
    def __str__(self):
        return f"{self.rank} of {self.suit}"

# %%
class CardDeck:
    import random
    def __init__(self):
        self.card_deck = []

        
        for rank in ranks:
            for suit in suits:
                card = Card(suit,rank)
                self.card_deck.append(card)
               
    def Shuffle(self):
        random.shuffle(self.card_deck)
    def deal(self):
        return self.card_deck.pop(0)

# %%
class BJplayer():
    def __init__(self,name):
        self.name = name
        self.BJplayer_cards = []
        self.BJplayer_table = []
        self.BJplayer_money = 100
    def add_cards(self,cards):
        self.cards = cards
        if type(cards) == type([]):
             self.BJplayer_cards.extend(cards)
        else:
             self.BJplayer_cards.append(cards) 
    def deal(self):
        return BJplayer_cards.pop(0)
    def Shuffle_all_cards(self):
        random.shuffle(self.BJplayer_cards)
    def BJplayer_table_add(self):
        self.BJplayer_table.append(self.BJplayer_cards.pop(0))
    def shuffle_table_cards(self):
        random.shuffle(self.BJplayer_table)
    def display(self):              # I need to give input the number of cards that needs to display (based on that we can minus the money)
        print(self.BJplayer_table[-1])
        print("Card 2 is in hidden state")
    def clear_table(self):
        self.BJplayer_table = []  # the existing cards in table is totaly removed from the existance in this game

# %%
new_game = True
player_1_money = 100
player_2_money = 100
while new_game: 
    print("ooooooooooooooooooooooooooooooooooooooooooooo NEW GAME ooooooooooooooooooooooooooooooooooooooooooooooooooo")
    rounds = 1 
    AtWar = True
    while AtWar:
        print(f"@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ ROUND {rounds} @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
        Game = CardDeck()
        Game.Shuffle()

        player_1 = BJplayer("player_1")
        player_2 = BJplayer("player_2")
        for n in range(26):
            player_1.add_cards(Game.deal())
            player_2.add_cards(Game.deal())
        
        player_1.Shuffle_all_cards()
        player_2.Shuffle_all_cards()
        
        player_1.BJplayer_table_add()
        player_1.BJplayer_table_add()    

        player_2.BJplayer_table_add()
        player_2.BJplayer_table_add()

        print("######################################      Player 1 Cards      ############################################")
        print(f" the first card is:  {player_1.BJplayer_table[0]}")
        print("second card is hidden")
        print("######################################      Player 2 Cards      ############################################")
        print(f"  the first card is:  {player_2.BJplayer_table[0]}")
        print("second card is hidden")


            # player_1.Shuffle_all_cards() - i dont want to shuffle the player cards

            # player_2.Shuffle_all_cards()  - i dont want to shuffle the player cards

        add_player1 = True
        print("#######################################      Player 1 Cards      ##########################################")
        while add_player1:
            add_1 = input("player 1 do you want to add a card (y/n)  ")
            if add_1[0] == "y":
                player_1.BJplayer_table_add()
                print(f" the first card is:  {player_1.BJplayer_table[0]}")
                print(f" the second card is:  {player_1.BJplayer_table[1]}")
                print("other cards are hidden")
            else:
                add_player1 = False
        print("########################################      Player 2 Cards  #############################################")
        add_player2 = True        
        while add_player2:
            add_2 = input("player 2 do you want to add a card (y/n)  ")
            if add_2[0] == "y":
                player_2.BJplayer_table_add()
                print(f" the first card is:  {player_2.BJplayer_table[0]}")
                print(f" the second card is:  {player_2.BJplayer_table[1]}")
                print("other cards are hidden")
            else:
                add_player2 = False     


        print("###################### $ $ $ $ $ $ $ $ $ $     BETTING TIME  $ $ $ $ $ $ $ $ $ $ $ ########################")
            # player_1_bet,player_2_bet = Betting()
        while True:
            player_1_bet = input("player_1 enter the bet money   ")
            if int(player_1_bet) > player_1_money:
                print("Please enter a valid betting amount ")
            else:
                break
        while True:   
            player_2_bet = input("player_2 enter the bet money   ")
            if int(player_2_bet) > player_2_money:
                print("Please enter a valid betting amount ")
            else:
                break

        print("####################### # # # # # # # # # # # #    RESULT  # # # # # # # # # # # # ########################") 
        value_1 = 0
        value_2 = 0
        for a in player_1.BJplayer_table:
            value_1 = a.value + value_1
        for b in player_2.BJplayer_table:
            value_2 = b.value + value_2
                ## print(self.value_1)
                # print(self.value_2)
        if value_1 == 21:
            player_2_money =  player_2_money-int(player_2_bet)
            print("Player one wins, BLACKJACK PERFECT")
            AtWar = False

        elif value_2 == 21:
            player_1_money = player_1_money-int(player_1_bet)
            print("Player two wins, BLACKJACK PERFECT")
            AtWar = False

        elif value_1 > 21 and value_2 > 21:
            print("Both player are BUSTED")
            AtWar = False

        elif value_1 == value_2 == 21:
            print("Both player BLACKJACK PERFECT, VERY rare hit !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! ")
            AtWar = False

        elif value_1 > 21:
            player_1_money = player_1_money-int(player_1_bet)
            print("Player one BUSTED, so player two WINS")
            AtWar = False

        elif value_2 > 21:
            player_2_money =  player_2_money-int(player_2_bet)
            print("Player two BUSTED, so player one WINS") 
            AtWar = False

        elif value_1 < 21 and value_2 < 21:
            print("its a WARR !!!!!!!!!!!!!!")
            add_player2 = True        
            while add_player1:
                add_1 = input("player 1 do you want to add a card (y/n)  ")
                if add_1[0] == "y":
                    player_1.BJplayer_table_add()
                    print(f" the first card is:  {player_1.BJplayer_table[0]}")
                    print(f" the second card is:  {player_1.BJplayer_table[1]}")
                    print("other cards are hidden")
                else:
                    add_player1 = False
            add_player2 = True        
            while add_player2:
                add_2 = input("player 2 do you want to add a card (y/n)  ")
                if add_2[0] == "y":
                    player_2.BJplayer_table_add()
                    print(f" the first card is:  {player_2.BJplayer_table[0]}")
                    print(f" the second card is:  {player_2.BJplayer_table[1]}")
                    print("other cards are hidden")
                else:
                    add_player2 = False 
        ##################################################################################################################

        print("######################   |^||^||^||^||^|   Player one Table   |^||^||^||^||^|    ##########################")
        print(f"player 1 has {player_1_money} left in his wallet")
        for a in player_1.BJplayer_table:
            print(a)
        print(f"the value of the cards owned by player_1 is {value_1}")
        print("######################  |^||^||^||^||^|  Player two Table   |^||^||^||^||^|     ############################")
        print(f"player 2 has {player_2_money} left in his wallet")
        for b in player_2.BJplayer_table:
            print(b)
        print(f"the value of the cards owned by player_2 is {value_2}")
        
        
        if player_1_money == 0:
            print("*** Player_1 has no mony to bet the game is over PLAYER 2 WINS the BLACKJACK ***")
            new_game = False
        elif player_2_money == 0:
            print("*** Player_2 has no mony to bet the game is over PLAYER 1 WINS the BLACKJACK ***")
            new_game = False
        else:
            pass


        if value_1 > 21 or value_2 > 21 or value_1 == 21 or value_2 == 21:
            player_1.clear_table()
            player_2.clear_table()            
        else:
            pass

    ##################################################################################################################    
        if player_1_money != 0 and player_2_money != 0:
            cont = input("do you want to continue (y/n):  ")
            if cont[0] == "y":
                AtWar = True
                rounds = rounds+1
            else:
                AtWar = False
        elif player_1_money == 0 and player_2_money == 0:
            AtWar = False

    print("ooooooooooooooooooooooooooooooooooooooooooooo GAME OVER ooooooooooooooooooooooooooooooooooooooooooooooooo")
    new = input("Do you want to start a new game (y/n) ") 
    if new[0] == "y": 
        new_game = True 
    else: 
        new_game = False

# %%
   elif value_1 < 21 and value_2 < 21:
        print("its a WARR !!!!!!!!!!!!!!")
        add_player2 = True        
        while add_player2:
            add_2 = input("player 2 do you want to add a card (y/n)  ")
            if add_2[0] == "y":
                player_2.BJplayer_table_add()
                print(f" the first card is:  {player_2.BJplayer_table[0]}")
                print(f" the second card is:  {player_2.BJplayer_table[1]}")
                print("other cards are hidden")
            else:
                add_player2 = False
        add_player2 = True        
        while add_player2:
            add_2 = input("player 2 do you want to add a card (y/n)  ")
            if add_2[0] == "y":
                player_2.BJplayer_table_add()
                print(f" the first card is:  {player_2.BJplayer_table[0]}")
                print(f" the second card is:  {player_2.BJplayer_table[1]}")
                print("other cards are hidden")
            else:
                add_player2 = False

# %%
def show_player_table(self):
        print(f"player 1 has {player_1.BJplayer_money} left in his wallet")
        for a in player_1_table:
            print(a)
        print(self.value_1)
        print("Player two cards ##########")
        print(f"player 2 has {player_2.BJplayer_money} left in his wallet")
        for b in player_2_table:
            print(b)
        print(self.value_2)

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@   BLACK JACK AUTOMATIC  @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
suits = ["hearts", "diamonds", "spades","clubs"]
ranks = ["two","three","four","five","six","seven","eight","nine","ten","jack","queen","king","ace"]
value = {"one":1,"two":2,"three":3,"four":4,"five":5,"six":6,"seven":7,"eight":8,"nine":9,"ten":10,"jack":10,"queen":10,"king":10,"ace":11}

# %%
import random
class Card():
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = value[rank]
    def value(self):
        self.value = value[rank]
        
    def __str__(self):
        return f"{self.rank} of {self.suit}"

# %%
class CardDeck:
    import random
    def __init__(self):
        self.card_deck = []

        
        for rank in ranks:
            for suit in suits:
                card = Card(suit,rank)
                self.card_deck.append(card)
               
    def Shuffle(self):
        random.shuffle(self.card_deck)
    def deal(self):
        return self.card_deck.pop(0)

# %%
class BJplayer():
    def __init__(self,name):
        self.name = name
        self.BJplayer_cards = []
        self.BJplayer_table = []
        self.BJplayer_money = 100
    def add_cards(self,cards):
        self.cards = cards
        if type(cards) == type([]):
             self.BJplayer_cards.extend(cards)
        else:
             self.BJplayer_cards.append(cards) 
    def deal(self):
        return BJplayer_cards.pop(0)
    def Shuffle_all_cards(self):
        random.shuffle(self.BJplayer_cards)
    def BJplayer_table_add(self):
        self.BJplayer_table.append(self.BJplayer_cards.pop(0))
    def shuffle_table_cards(self):
        random.shuffle(self.BJplayer_table)
    def display(self):              # I need to give input the number of cards that needs to display (based on that we can minus the money)
        print(self.BJplayer_table[-1])
        print("Card 2 is in hidden state")
    def clear_table(self):
        self.BJplayer_table = []  # the existing cards in table is totaly removed from the existance in this game

# %%
def game_rules():
        print("######################################### GAME RULES  ##################################################################")
        print("A card deck has 52 cards, with ranks two to ten and aditional ranks like jack,queen,king and Ace ")
        print("We have four Suits (hearts, diamonds, spades,clubs)")
        print("We have unique and individual cards with each Suit with a rank")
        print("in black jack we consider the value of jack,queen,king as 10 and rank of Ace as 11 ")
        print("Here the cards are shuffled well and shared between the players so each player have 26 cards each")
        print("Each player have 100 Rupees to bet if a player looses all the money he looses the game and need to start a new game")
        print("there will multiple rounds based on the bet we place")
        print("Winner of each round is dicided by bellow 3 rules")
        print("Rule 1: If any player hits value 21, that player wins")
        print("Rule 2: If one player hits value more than 21 the other player wins automatically ")
        print("Rule 3: If both player values are bellow 21 then whoever values is near to 21 wins the round")
        print("Have a good game")
        print(".......................................................................................................................")

# %%
# You are player_1
# Computer is named Ben player_2


new_game = True
while new_game: 
    print("ooooooooooooooooooooooooooooooooooooooooooooo NEW GAME ooooooooooooooooooooooooooooooooooooooooooooooooooooooooo")
    print("Ben: Hi, Good to see you. this is Ben in your opponent............")
    player_name  = input("Ben: what is your your name ......... :  ")
    print(f"Ben: Hey {player_name} great name, Hope you are a worthy oppenent.........")
    Rules = input(f"Ben: Hey {player_name} do you want to know the game rules (y/n).........." )
    if Rules[0] == "y":
        game_rules()
    else:
        pass
    player_1_money = 100
    player_2_money = 100
    rounds = 1 
    AtWar = True
    while AtWar:
        print(f"@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ ROUND {rounds} @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
        Game = CardDeck()
        Game.Shuffle()

        player_1 = BJplayer("player_1")
        player_2 = BJplayer("player_2")
        for n in range(26):
            player_1.add_cards(Game.deal())
            player_2.add_cards(Game.deal())
        
        player_1.Shuffle_all_cards()
        player_2.Shuffle_all_cards()
        
        player_1.BJplayer_table_add()
        player_1.BJplayer_table_add()    

        player_2.BJplayer_table_add()
        player_2.BJplayer_table_add()

        print(f"######################################      {player_name}'s Cards      ############################################")
        print(f" the first card is:  {player_1.BJplayer_table[0]}")
        print(f" the second card is:  {player_1.BJplayer_table[1]}")
    #    print("######################################      Player 2 Cards      ############################################")
    #   print(f"  the first card is:  {player_2.BJplayer_table[0]}")
    #   print("second card is hidden")


            # player_1.Shuffle_all_cards() - i dont want to shuffle the player cards

            # player_2.Shuffle_all_cards()  - i dont want to shuffle the player cards

        add_player1 = True
        print(f"#######################################      {player_name}'s Cards     ############################################")
        while add_player1:
            add_1 = input(f"{player_name} do you want to add a card (y/n)  ")
            if add_1[0] == "y":
                player_1.BJplayer_table_add()
                print(f" the first card is:  {player_1.BJplayer_table[0]}")
                print(f" the second card is:  {player_1.BJplayer_table[1]}")
                print("other cards are hidden")
            else:
                add_player1 = False
        # print("########################################      Player 2 Cards  #############################################")
        add_player2 = True
        
        while add_player2:
            val = 0
            for a in player_2.BJplayer_table: 
                 val = a.value + val
            if val < 15:
    
                player_2.BJplayer_table_add()
                print("Ben has taken a card.....")
            else:
                add_player2 = False  

    #     add_player2 = True        
    #   while add_player2:
    
    #        add_2 = input("player 2 do you want to add a card (y/n)  ")
    #        if add_2[0] == "y":
    #            player_2.BJplayer_table_add()
    #            print(f" the first card is:  {player_2.BJplayer_table[0]}")
    #            print(f" the second card is:  {player_2.BJplayer_table[1]}")
    #           print("other cards are hidden")
    # #       else:
    #            add_player2 = False     


        print("###################### $ $ $ $ $ $ $ $ $ $     BETTING TIME  $ $ $ $ $ $ $ $ $ $ $ ########################")
            # player_1_bet,player_2_bet = Betting()
        while True:
            player_bet = input(f"Ben: Hey {player_name}, So what is your bet. enter the bet money..... :   ")
            if int(player_bet) > player_1_money or int(player_bet) > player_2_money:
                print("Please enter a valid betting amount ")
            else:
                break
      #  while True:   
      #      player_2_bet = input("player_2 enter the bet money   ")
      #      if int(player_2_bet) > player_2_money:
      #          print("Please enter a valid betting amount ")
      #      else:
       #         break

        print("####################### # # # # # # # # # # # #    RESULT  # # # # # # # # # # # # ########################") 
        value_1 = 0
        value_2 = 0
        for a in player_1.BJplayer_table:
            value_1 = a.value + value_1
        for b in player_2.BJplayer_table:
            value_2 = b.value + value_2
                ## print(self.value_1)
                # print(self.value_2)
        if value_1 == 21:
            player_2_money =  player_2_money-int(player_bet)
            print(f"{player_name} wins, BLACKJACK PERFECT...")
            print(f"Ben: Hey {player_name}, you got some luck i guess..... ")
            AtWar = False

        elif value_2 == 21:
            player_1_money = player_1_money-int(player_bet)
            print(f"Ben wins, BLACKJACK PERFECT {player_name} LOOSE..")
            print(f"Ben: hahaha you lose, you got no talent for this game.....")
            AtWar = False

        elif value_1 > 21 and value_2 > 21:
            print("Both player are BUSTED")
            print("Ben: No comments simply waste......")
            AtWar = False

        elif value_1 == value_2 == 21:
            print("Both player BLACKJACK PERFECT, VERY rare hit !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! ")
            print(f"Ben: I won by talent, Not sure about you........")
            AtWar = False

        elif value_1 > 21:
            player_1_money = player_1_money-int(player_bet)
            print(f"{player_name} BUSTED, so Ben WINS")
            print("Ben: I think i over estimated, you are a trash..... ")
            AtWar = False

        elif value_2 > 21:
            player_2_money =  player_2_money-int(player_bet)
            print(f"Ben BUSTED, so {player_name} WINS") 
            print("Ben: Tskk, i got distracted by your ugliness.....")
            AtWar = False

        elif value_1 < 21 and value_2 < 21:
            if value_1 > value_2:
                player_2_money = player_2_money-int(player_bet)
                print(f"{player_name} is near to 21, so {player_name} wins")
                print("Ben: Tskk, i got distracted by your ugliness.....")
                
            elif value_1 < value_2:
                player_1_money = player_1_money-int(player_bet)
                print("Ben is near to 21, so Ben wins")
            elif value_1 == value_2:
                print("Both player have cards of same value, draw")
                print(f"Ben: This game is not for everyone, talented people only can win....... ")
                    
           
                        
        #        add_2 = input("player 2 do you want to add a card (y/n)  ")
        #        if add_2[0] == "y":
       ##             player_2.BJplayer_table_add()
       #             print(f" the first card is:  {player_2.BJplayer_table[0]}")
        #            print(f" the second card is:  {player_2.BJplayer_table[1]}")
        #            print("other cards are hidden")
       #         else:
       #             add_player2 = False 
        ##################################################################################################################

        print(f"#########################   |^||^||^||^||^|  {player_name}'s Table   |^||^||^||^||^|  ##############################")
        print(f"{player_name} has {player_1_money} left in his wallet")
        for a in player_1.BJplayer_table:
            print(a)
        print(f"the value of the cards owned by {player_name} is {value_1}")
        print("########################  |^||^||^||^||^|  Ben's Table   |^||^||^||^||^|   ######################################")
        print(f"Ben has {player_2_money} left in his wallet")
        for b in player_2.BJplayer_table:
            print(b)
        print(f"the value of the cards owned by Ben is {value_2}")
        
        
        if player_1_money == 0:
            print(f"*** {player_name} has no money to bet the game is over Ben WINS the BLACKJACK ***")
            print("Ben: Hey Looser, want to play again........ ")
            new_game = False
        elif player_2_money == 0:
            print(f"*** Ben has no money to bet the game is over {player_name} WINS the BLACKJACK ***")
            print("Ben: Hey you got some moves, it was a good game. I hope we match again .......")
            new_game = False
        else:
            pass


        if value_1 > 21 or value_2 > 21 or value_1 == 21 or value_2 == 21:
            player_1.clear_table()
            player_2.clear_table()            
        else:
            pass

    ##################################################################################################################    
        
        if player_1_money == 0 or player_2_money == 0:
            AtWar = False
        else:
            cont = input(f"Ben: Hey {player_name} do you want to bet again ? (y/n)......:  ")
            if cont[0] == "y":
                AtWar = True
                rounds = rounds+1
            else:
                AtWar = False

    print("ooooooooooooooooooooooooooooooooooooooooooooo GAME OVER ooooooooooooooooooooooooooooooooooooooooooooooooo")
    new = input("Ben: Hey it was a great game though, want to play again? NEW GAME (y/n)...... ") 
    if new[0] == "y": 
        new_game = True 
    else: 
        new_game = False
# Out:
# ooooooooooooooooooooooooooooooooooooooooooooo NEW GAME ooooooooooooooooooooooooooooooooooooooooooooooooooooooooo
# Ben: Hi, Good to see you. this is Ben in your opponent............
# Ben: what is your your name ......... :  SUD
# Ben: Hey SUD great name, Hope you are a worthy oppenent.........
# Ben: Hey SUD do you want to know the game rules (y/n)..........n
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ ROUND 1 @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# ######################################      SUD's Cards      ############################################
#  the first card is:  three of diamonds
#  the second card is:  king of diamonds
# #######################################      SUD's Cards     ############################################
# SUD do you want to add a card (y/n)  y
#  the first card is:  three of diamonds
#  the second card is:  king of diamonds
# other cards are hidden
# SUD do you want to add a card (y/n)  n
# Ben has taken a card.....
# ...
